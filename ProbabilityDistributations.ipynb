# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
#setting seabon color style
sns.set(color_codes=True)
#settings for seaborn plot sizes
sns.set(rc = {'figure.figsize':(10,7)})

# %%
from scipy.stats import uniform

# %% [markdown]
# generating 10 random uniform distributions from 0 to 10

# %%
n = 10000
a = 0
b = 10
data_uniform = uniform.rvs(size = n,loc = a,scale = b)

# %%
#plotting the uniform distribution using distplot

ax = sns.distplot(data_uniform,bins = 10,color= 'red')
ax.set(xlabel = 'uniform',ylabel = 'freq')
# Out:
# [Text(0, 0.5, 'freq'), Text(0.5, 0, 'uniform')]

# %%
ax = sns.distplot(data_uniform,bins = 10,color = 'red',kde = False,
                 hist_kws = {'linewidth':15})

# %%
data_uniform
# Out:
# array([8313.50936878, 7337.89058353, 6142.0301391 , ..., 6403.67293741,
#         692.57671261, 8169.68243868])

# %% [markdown]
# Generate random numbers for normal distributions

# %%
from scipy.stats import norm

# %%
data_normal = norm.rvs(size = 10000,loc = 0,scale = 1)

# %%
data_normal
# Out:
# array([ 1.06980165, -0.02127263, -0.54377178, ..., -1.13071604,
#        -1.12429271, -0.25419615])

# %%
ax = sns.distplot(data_normal,bins = 100,color = 'purple')

# %%
max(data_normal)
# Out:
# 4.465043949921595

# %% [markdown]
# Generating random numbers for bernoullo distribution

# %%
from scipy.stats import bernoulli

# %%
data_bern = bernoulli.rvs(size = 10000,p = .2) # p = success probability

# %%
ax = sns.distplot(data_bern,color = 'black',
                  hist_kws = {"linewidth":15,'alpha':1})
ax.set(xlabel='Bernoulli', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Bernoulli')]

# %% [markdown]
# Generating distributions for binomial distribuitons

# %%
from scipy.stats import binom

# %%
binom.rvs(n = 10,p = 0.5,size = 5)
# Out:
# array([3, 6, 3, 6, 6])

# %%
data_binom = binom.rvs(n = 10,p = 0.5,size = 10000)
ax = sns.distplot(data_binom,color = 'orange', 
                  hist_kws = {"linewidth":15,'alpha':1})

# %% [markdown]
# Generate Random numbers for poisson distribution

# %%
from scipy.stats import poisson

# %%
data_poisson = poisson.rvs(mu = 3,size = 10000)
data_poisson
# Out:
# array([4, 0, 5, ..., 5, 5, 2])

# %%
ax = sns.distplot(data_poisson,color = 'blue',hist_kws = {'linewidth':15,'alpha':1})

# %% [markdown]
# # Generate random numbers for beta distribution

# %%
from scipy.stats import beta
data_beta = beta.rvs(1,1,size = 10000)
ax = sns.distplot(data_beta,color= 'red',bins = 100)

# %% [markdown]
# Let us generate 10000, random numbers from Beta distribution with alpha = 10 and beta = 1. The histogram of Beta(10,1) is skewed towards right.

# %% [markdown]
# # generate random numbers for gamme distributions

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a = 5,size = 10000)
ax = sns.distplot(data_gamma,bins = 100,color = 'yellow')

# %% [markdown]
# # generate random numbers for log normal distribution

# %%
from scipy.stats import lognorm
data_lognorm = lognorm.rvs(0.2,size = 10000)
sns.distplot(data_lognorm,bins = 100,color = 'orange')

# %% [markdown]
# # generate random numbers for negative binomial

# %%
from scipy.stats import nbinom

# %%
data_nbi = nbinom.rvs(10,0.5,size = 10000)
sns.distplot(data_nbi,color = 'skyblue')
